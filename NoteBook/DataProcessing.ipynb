# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', sep=";", quotechar='"')

# %%
df
# Out:
#      type                    "name"                     "description"  \
# 0     eat              "Bun Bo Hue"          "spicy beef noodle soup"
# 1     eat        "Banh Canh Ca Loc"          "thick fish noodle soup"
# 2     eat              "Banh Khoai"         "crispy turmeric pancake"
# 3     eat                "Banh Nam"         "steamed rice flour cake"
# 4     eat            "Banh Bot Loc"   "clear shrimp tapioca dumpling"
# ..    ...                       ...                               ...
# 295  stay   "Happy Buddha Homestay"                        "homestay"
# 296  stay        "Terracotta Villa"                           "villa"
# 297  stay     "Ngoc Lan Guesthouse"                        "homestay"
# 298  stay     "Hue Downtown Hostel"                          "hostel"
# 299  stay       "Harmony Hue Hotel"                           "hotel"
#
#            "time"                     "price"              "location"  \
# ...

# %%
df.drop_duplicates(subset = 'note')df.columns = df.columns.str.strip().str.strip('"')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_8070/1577441413.py in ?()
# ----> 1 df.drop_duplicates(subset = 'note')
#
# ~/.local/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, subset, keep, inplace, ignore_index)
#    6814
#    6815         inplace = validate_bool_kwarg(inplace, "inplace")
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#    6821
#
# ~/.local/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
#    6948         diff = set(subset) - set(self.columns)
# ...

# %%
# Out:
#      type                      name                       description  \
# 0     eat              "Bun Bo Hue"          "spicy beef noodle soup"
# 1     eat        "Banh Canh Ca Loc"          "thick fish noodle soup"
# 2     eat              "Banh Khoai"         "crispy turmeric pancake"
# 3     eat                "Banh Nam"         "steamed rice flour cake"
# 4     eat            "Banh Bot Loc"   "clear shrimp tapioca dumpling"
# ..    ...                       ...                               ...
# 295  stay   "Happy Buddha Homestay"                        "homestay"
# 296  stay        "Terracotta Villa"                           "villa"
# 297  stay     "Ngoc Lan Guesthouse"                        "homestay"
# 298  stay     "Hue Downtown Hostel"                          "hostel"
# 299  stay       "Harmony Hue Hotel"                           "hotel"
#
#              time                       price                location  \
# ...

# %%
df = pd.read_csv('data.csv', sep=";", quotechar='"')
